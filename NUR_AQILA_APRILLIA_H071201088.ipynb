# %% [markdown]
# **TUGAS 2 PERTEMUAN 3**
#
# NAMA : NUR AQILA APRILLIA
#
# NIM : H071201088
#
# PRODI : SISTEM INFORMASI

# %% [markdown]
# **1. Cara mengambil data dari kaggle (tanpa harus mendownload datanya terlebih dahulu)**
#
# ---

# %% [markdown]
# *   Menggunakan library OS

# %%
import os
import pandas as pd

# %% [markdown]
# *   menyiapkan API dari kaggle, dengan membuka profil kaggle yang dimiliki

# %% [markdown]
# ![1.PNG](data:image/png;base64,...)

# %% [markdown]
# *   Masukkan username dan key yang telah didaptkan dari API yang telah kita buat sebelumnya

# %%
os.environ['KAGGLE_USERNAME'] = "nuraqilaaprillia"
os.environ['KAGGLE_KEY'] = "0915d23a16a36263a973695e0d889654"

# %% [markdown]
# *   Ambil link dari dataset yang diinginkan di kaggle
#
# ![2.PNG](data:image/png;base64,...)

# %% [markdown]
# *   Lalu masukkan dalam syntax dibawah ini

# %%
# !kaggle datasets download -d nypl/whats-on-the-menu
# Out:
# ...
#  78% 27.0M/34.7M [00:00<00:00, 116MB/s]
# 100% 34.7M/34.7M [00:00<00:00, 137MB/s]

# %% [markdown]
# ekstraks hasil dowload dengan sytax berikut

# %%
# !unzip -q /content/whats-on-the-menu.zip

# %% [markdown]
# hasilnya dapat dilihat dengan menambahkan variable dan read.csv

# %%
data = pd.read_csv("Dish.csv")
data
# Out:
#             id  ... highest_price
# 0            1  ...           0.4
# 1            2  ...           0.8
# 2            3  ...           0.4
# 3            4  ...           1.0
# 4            5  ...          18.0
# ...        ...  ...           ...
# 422034  514315  ...           0.0
# 422035  514316  ...           0.0
# 422036  514317  ...           0.0
# 422037  514318  ...           0.0
# 422038  514319  ...           0.0
#
# [422039 rows x 9 columns]

# %% [markdown]
# **2. Mengambil data dari dokumen device masing-masing**
#
#
# ---

# %% [markdown]
#
#
# *   kita mengggunakan library google colabs untuk mengistal file (pilih choose file)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-cd5c68b5-b4ff-4ae2-aabe-25b26dd5d882" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cd5c68b5-b4ff-4ae2-aabe-25b26dd5d882">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving movies.csv to movies.csv

# %% [markdown]
# * setelah filenya telah masuk dalam google colab, kita menggunakan library io.

# %%
import io

# %% [markdown]
# *   ambil nama path dari data yang telah kita pilih lalu masukkan seprti syntax dibawah ini agar dapa terbaca oleh google colabs
#
#
#
# *perhatikan untuk membaca suatu file harus melihat format file tersebut dan menyamakannya dengan metodenya pd.read_ *

# %%
data1 = pd.read_csv(io.BytesIO(uploaded['movies.csv']))
data1
# Out:
#                                                 name  ... runtime
# 0                                        The Shining  ...   146.0
# 1                                    The Blue Lagoon  ...   104.0
# 2     Star Wars: Episode V - The Empire Strikes Back  ...   124.0
# 3                                          Airplane!  ...    88.0
# 4                                         Caddyshack  ...    98.0
# ...                                              ...  ...     ...
# 7663                                    More to Life  ...    90.0
# 7664                                     Dream Round  ...    90.0
# 7665                                   Saving Mbango  ...     NaN
# 7666                                    It's Just Us  ...   120.0
# 7667                                       Tee em el  ...   102.0
#
# [7668 rows x 15 columns]

# %% [markdown]
# **3. Mengambil data dari url**
#
#
# ---

# %% [markdown]
# *  disini saya menggunakan github untuk mengambil url dari suatu data, jika sudah menemukan data dari github, tekan **Raw** untuk mengambil url dari data tersebut
# ![Capture.PNG](data:image/png;base64,...)

# %% [markdown]
# *   setelah menekan raw, maka akan tampil halaman seperti ini. copy link data tersebut ![4.PNG](data:image/png;base64,...)

# %% [markdown]
# *   menggunakan library panda dan memasukkan url dari data tersebut

# %%
data2 = pd.read_csv("https://raw.githubusercontent.com/Abdallah-Medhat/animals-classification/main/zoo.csv")
data2
# Out:
#     animal_name  hair  feathers  eggs  ...  tail  domestic  catsize  class_type
# 0      aardvark     1         0     0  ...     0         0        1           1
# 1      antelope     1         0     0  ...     1         0        1           1
# 2          bass     0         0     1  ...     1         0        0           4
# 3          bear     1         0     0  ...     0         0        1           1
# 4          boar     1         0     0  ...     1         0        1           1
# ..          ...   ...       ...   ...  ...   ...       ...      ...         ...
# 96      wallaby     1         0     0  ...     1         0        1           1
# 97         wasp     1         0     1  ...     0         0        0           6
# 98         wolf     1         0     0  ...     1         0        1           1
# 99         worm     0         0     1  ...     0         0        0           7
# 100        wren     0         1     1  ...     1         0        0           2
#
# ...

# %% [markdown]
# **4. Mengambil data dari file json**
#
# bentuk keluaran file ini berupa format json
#
# ---

# %% [markdown]
# *   menggunakan library json

# %%
import json

# %% [markdown]
# *   pertama download file dengan format json, kemudian pilih menu bar seblah kanan
#
# ![1.PNG](data:image/png;base64,...)

# %% [markdown]
# * klik icon seperti gambar dibawah ini, lalu pilih file json yang telah anda download
#
# ![2.PNG](data:image/png;base64,...)

# %% [markdown]
# * setelah nama file telah tampil seperti di bawah ini
#
# ![5.PNG](data:image/png;base64,...)

# %% [markdown]
# * klik kanan pada file lalu copy path
#
# ![6.PNG](data:image/png;base64,...)

# %% [markdown]
# *    path dari data tersebut lalu masukkan ke dalam sytax di bawah ini:

# %%
f = open('/content/jobs.json',)
data3 = json.load(f)

# %%
data3
# Out:
# {'195884': {'categories': ['.net',
#    'elasticsearch',
#    'rest',
#    'sql-server',
#    'entity-framework'],
#   'query': 'visual studio 2015.txt',
#   'title': '.NET Developer at Suzy (New York, NY)'},
#  '204934': {'categories': ['.net', 'c#', 'javascript', 'sql', 'apache-spark'],
#   'query': 'zend framework.txt',
#   'title': 'Sr. Software Engineer (.Net) at Cheetah Digital (Cyberjaya, Malaysia)'},
#  '200051': {'categories': ['c#',
#    'asp.net',
#    'angular',
#    'angularjs',
#    'machine-learning'],
#   'query': 'windows server.txt',
#   'title': 'Full-Stack .NET Developer at ThoughtTrace (Magnolia, TX)'},
#  '205331': {'categories': ['java',
#    'c#',
#    '.net',
#    'artificial-intelligence',
#    'chatbot'],
#   'query': 'xamarin test cloud.txt',
#   'title': 'Software Engineer (Multi platform - Java/. Net) at Telstra (Melbourne, Australia)'},
#  '171562': {'categories': ['c#', '.net', 'sql-server', 'wpf', 'asp.net'],
#   'query': 'xamarin test cloud.txt',
# ...

# %% [markdown]
# **5. Mengambil data dengan package yang belum tersedia**
#
# ---

# %% [markdown]
# kasus : format data tersebut tidak tersedia librarynya secara langsung

# %% [markdown]
# *   pertama download file dengan format sav, kemudian pilih menu bar sebelah kanan
#
# ![1.PNG](data:image/png;base64,...)

# %% [markdown]
# * klik icon seperti gambar dibawah ini, lalu pilih file json yang telah anda download
#
# ![2.PNG](data:image/png;base64,...)

# %% [markdown]
# * setelah nama file telah tampil seperti di bawah ini
#
# ![3.PNG](data:image/png;base64,...)

# %% [markdown]
# * klik kanan pada file lalu copy path
#
#
#
#
# ![4.PNG](data:image/png;base64,...)

# %% [markdown]
# *   Install manual librarynya terlebih dahulu
# penginstalan dilakukan hanya sekali jika tidak menggunakan cloud

# %%
pip install pyreadstat
# Out:
# ...
#      |████████████████████████████████| 2.5 MB 2.6 MB/s
# ...

# %% [markdown]
# *   lalu import library yang telah kita install dengan sytax di bawah ini :

# %%
import pyreadstat

# %% [markdown]
# * buat sebuah variable, lalu copy path seperti syntax di bawah ini

# %%
df_loan, meta = pyreadstat.read_sav('/content/loan_roc.sav')

# %% [markdown]
# * print untuk melihat data tersebut

# %%
df_loan
# Out:
#      age  education  year_emp  income  ...  PGR_1  Dis_1    Dis1_1   Discrim
# 0   47.0        1.0      22.0    81.0  ...    0.0    0.0  0.988438  0.011562
# 1   40.0        1.0      22.0    95.0  ...    0.0    0.0  0.973334  0.026666
# 2   35.0        1.0      16.0    36.0  ...    0.0    0.0  0.988864  0.011136
# 3   43.0        1.0      16.0    89.0  ...    0.0    0.0  0.974100  0.025900
# 4   47.0        1.0      26.0   100.0  ...    0.0    0.0  0.931966  0.068034
# ..   ...        ...       ...     ...  ...    ...    ...       ...       ...
# 95  28.0        3.0       6.0    47.0  ...    1.0    1.0  0.041077  0.958923
# 96  34.0        1.0      12.0    68.0  ...    1.0    1.0  0.053560  0.946440
# 97  23.0        2.0       0.0    17.0  ...    1.0    1.0  0.022267  0.977733
# 98  35.0        2.0      11.0    62.0  ...    1.0    1.0  0.009707  0.990293
# 99  33.0        1.0      14.0    72.0  ...    1.0    1.0  0.000924  0.999076
#
# [100 rows x 13 columns]

# %% [markdown]
# # **fungsi pengubahan data dengan dari sav ke spss ini adalah agar nilai yang di ringkas dalam sav dapat terlihat jelas maksud dari ringkasan suatu nilai **

# %% [markdown]
# * untuk melihat file dengan format spssnya, buat variable baru, lalu copy path tersebut lalu masukkan ke dalam syntax seperti dibawah ini

# %%
df_sul1 = pd.read_spss("/content/loan_roc.sav")

# %% [markdown]
# * print untuk melihat data tersebut

# %%
df_sul1
# Out:
#      age                     education  year_emp  ...  Dis_1    Dis1_1   Discrim
# 0   47.0  Did not complete high school      22.0  ...     No  0.988438  0.011562
# 1   40.0  Did not complete high school      22.0  ...     No  0.973334  0.026666
# 2   35.0  Did not complete high school      16.0  ...     No  0.988864  0.011136
# 3   43.0  Did not complete high school      16.0  ...     No  0.974100  0.025900
# 4   47.0  Did not complete high school      26.0  ...     No  0.931966  0.068034
# ..   ...                           ...       ...  ...    ...       ...       ...
# 95  28.0                  Some college       6.0  ...    Yes  0.041077  0.958923
# 96  34.0  Did not complete high school      12.0  ...    Yes  0.053560  0.946440
# 97  23.0            High school degree       0.0  ...    Yes  0.022267  0.977733
# 98  35.0            High school degree      11.0  ...    Yes  0.009707  0.990293
# 99  33.0  Did not complete high school      14.0  ...    Yes  0.000924  0.999076
#
# ...
